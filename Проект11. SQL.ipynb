# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цель:" data-toc-modified-id="Цель:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цель:</a></span></li><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных:</a></span></li><li><span><a href="#Схема-таблиц:" data-toc-modified-id="Схема-таблиц:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Схема таблиц:</a></span></li><li><span><a href="#Запросы:" data-toc-modified-id="Запросы:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Запросы:</a></span></li><li><span><a href="#Аналитика" data-toc-modified-id="Аналитика-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Аналитика</a></span><ul class="toc-item"><li><span><a href="#1.-Импорт-файлов" data-toc-modified-id="1.-Импорт-файлов-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>1. Импорт файлов</a></span></li><li><span><a href="#2.-Изучение-данных" data-toc-modified-id="2.-Изучение-данных-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>2. Изучение данных</a></span></li><li><span><a href="#3.-Проверка-типов-данных-на-корректность" data-toc-modified-id="3.-Проверка-типов-данных-на-корректность-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>3. Проверка типов данных на корректность</a></span></li><li><span><a href="#4.-Выбор-топ-10-городов-по-количеству-рейсов" data-toc-modified-id="4.-Выбор-топ-10-городов-по-количеству-рейсов-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>4. Выбор топ-10 городов по количеству рейсов</a></span></li><li><span><a href="#5.-Построить-графики:" data-toc-modified-id="5.-Построить-графики:-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>5. Построить графики:</a></span><ul class="toc-item"><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Выводы:</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод:</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# # Спрос на рейсы авиакомпании

# %% [markdown]
# Вы аналитик российской авиакомпании F9, выполняющей внутренние пассажирские перевозки. Важно понять предпочтения пользователей, покупающих билеты на разные направления.
#
# Вам предстоит изучить базу данных и проанализировать спрос пассажиров на рейсы в города, где проходят крупнейшие культурные фестивали.

# %% [markdown]
# У вас есть файлы с результатами запросов из предыдущих заданий.
#
# **query_1.csv** — результат первого запроса. В нём содержится такая информация:
#
# - *model* — **модель самолета;
# - *flights_amount* — количество рейсов для каждой модели самолетов *model* в сентябре 2018 года.
#
# **query_3.csv** — результат третьего запроса. В нём содержится такая информация:
#
# - *city* — город;
# - *average_flights* — среднее количество рейсов, прибывающих в город (*city*) за день в сентябре 2018 года.
#
#  Для этих двух наборов данных нужно:
#
# - импортировать файлы;
# - изучить данные в них;
# - проверить типы данных на корректность;
# - выбрать топ-10 городов по количеству рейсов;
# - построить графики: модели самолётов и количество рейсов, города и количество рейсов, топ-10 городов и количество рейсов;
# - сделать выводы по каждому из графиков, пояснить результат.
# ------

# %% [markdown]
# # Спрос на рейсы авиакомпании
#
# ## Цель:
# * изучить базу данных и проанализировать спрос пассажиров на рейсы в города, где проходят крупнейшие культурные фестивали
#
# ## Описание данных:
#
# 1) Таблица airports — информация об аэропортах:
# * airport_code — трёхбуквенный код аэропорта
# * airport_name — название аэропорта
# * city — город
# * timezone — временная зона
#
# 2) Таблица aircrafts — информация о самолётах:
# * aircraft_code — код модели самолёта
# * model — модель самолёта
# * range — дальность полёта
#
# 3) Таблица tickets — информация о билетах:
# * ticket_no — уникальный номер билета
# * passenger_id — персональный идентификатор пассажира
# * passenger_name — имя и фамилия пассажира
#
# 4) Таблица flights — информация о рейсах:
# * flight_id — уникальный идентификатор рейса
# * departure_airport — аэропорт вылета
# * departure_time — дата и время вылета
# * arrival_airport — аэропорт прилёта
# * arrival_time — дата и время прилёта
# * aircraft_code — id самолёта
#
# 5) Таблица ticket_flights — стыковая таблица «рейсы-билеты»
# * ticket_no — номер билета
# * flight_id — идентификатор рейса
#
# 6) Таблица festivals — информация о фестивалях
# * festival_id — уникальный номер фестиваля
# * festival_date — дата проведения фестиваля
# * festival_city — город проведения фестиваля
# * festival_name — название фестиваля
#
# ## Схема таблиц:
# * схема лежит на локальном компьютере
#
# ## Запросы:
#
# * q1
#
# SELECT
#
#     aircrafts.model as model,
#     COUNT(flights.departure_time) as filghts_amount
#
# FROM
#
#     flights
#     INNER JOIN aircrafts ON aircrafts.aircraft_code = flights.aircraft_code
#
# WHERE
#
#     (extract(MONTH FROM flights.departure_time) = 9)
#     and
#     (extract(YEAR FROM flights.departure_time) = 2018)
#
# GROUP BY model
#
# * q2
#
# SELECT
#
#     COUNT(flights.flight_id) as flights_amount,
#     CASE WHEN model LIKE 'Airbus%' THEN 'Airbus'
#         WHEN model LIKE 'Boeing%' THEN 'Boeing'
#         ELSE 'other' END AS type_aircraft
#
# FROM
#
#     aircrafts
#     INNER JOIN
#     flights
#     ON
#     flights.aircraft_code = aircrafts.aircraft_code
#
# WHERE
#
#     CAST(flights.departure_time  AS date) BETWEEN '2018-09-01' AND '2018-09-30'
#
# GROUP BY
#     type_aircraft
#
# * q3
#
# SELECT
#
#     subq.city AS city,
#     AVG(subq.flight_amount) AS average_flights
#
# FROM
#
#     (SELECT
#          COUNT(flights.flight_id) AS flight_amount,
#          airports.city AS city,
#          EXTRACT (day from CAST(flights.arrival_time AS date)) AS day
#      FROM
#          flights
#      INNER JOIN airports
#          ON airports.airport_code = flights.arrival_airport
#      WHERE
#          CAST(flights.arrival_time AS date) BETWEEN '2018-08-01' AND '2018-08-31'
#      GROUP BY
#          city,
#          day) AS subq
#
# GROUP BY
#     city;
#
# * q4
#
# SELECT
#
#     festival_name,
#     EXTRACT(WEEK FROM CAST(festival_date AS date)) AS festival_week
#
# FROM
#     festivals
# WHERE
#     festival_city = 'Москва' AND festival_date BETWEEN  '2018-07-23' AND '2018-09-30'
#
# * q5
#
# SELECT
#
#     EXTRACT(week FROM CAST(flights.arrival_time AS date)) AS week_number,
#     COUNT(ticket_flights.ticket_no) AS ticket_amount,
#     sub.festival_week AS festival_week,
#     sub.festival_name AS festival_name
#
# FROM tickets
#
#     LEFT JOIN ticket_flights ON ticket_flights.ticket_no  = tickets.ticket_no
#     LEFT JOIN flights ON flights.flight_id  = ticket_flights.flight_id
#     LEFT JOIN airports ON airports.airport_code = flights.arrival_airport
#     LEFT JOIN
#         (SELECT
#              festival_name,
#              EXTRACT(WEEK FROM CAST(festival_date AS date)) AS festival_week
#          FROM
#              festivals
#          WHERE
#              festival_city = 'Москва' AND festival_date BETWEEN '2018-07-23' AND '2018-09-30') as sub ON sub.festival_week = EXTRACT(week FROM CAST(flights.arrival_time AS date))
# WHERE
#     airports.city = 'Москва' AND
#     CAST(flights.arrival_time AS date) BETWEEN '2018-07-23' AND '2018-09-30'
# GROUP BY
#     EXTRACT(week FROM CAST(flights.arrival_time AS date)),
#     festival_week,
#     festival_name

# %% [markdown]
# ## Аналитика

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# ### 1. Импорт файлов

# %%
df_q1 = pd.read_csv('/datasets/query_1.csv').sort_values(by = 'flights_amount',ascending = False).reset_index(drop= True)
df_q3 = pd.read_csv('/datasets/query_3.csv').sort_values(by= 'average_flights', ascending =False).reset_index(drop=True)

# %% [markdown]
# ### 2. Изучение данных
# ### 3. Проверка типов данных на корректность

# %%
def get_data_report(df, name):
    print('Таблица: {}'.format(name))
    print('Размеры таблицы: число строк = {}, число колонок = {}'.format(df.shape[0], df.shape[1]))    
    print('Информация о признаках:')
    tab = pd.DataFrame()
    # проходим по признакам
    for col in df.columns:

        # текущий признак
        ser = df[col]



        v1 = ser.dtype        
        v2 = ser.isna().mean()
        try:
            v3 = ser.mean()   
        except:
            v3 = np.nan 
            
        tab.loc[col, 'тип'] = v1        
        tab.loc[col, 'доля_nan '] = v2
        tab.loc[col, 'среднее_значение'] = v3
    print(tab)

# %%
get_data_report(df_q1, 'query_1')
# Out:
# Таблица: query_1
# Размеры таблицы: число строк = 8, число колонок = 2
# Информация о признаках:
#                    тип  доля_nan   среднее_значение
# model           object        0.0               NaN
# flights_amount   int64        0.0          2035.625

# %%
get_data_report(df_q3, 'query_3')
# Out:
# Таблица: query_3
# Размеры таблицы: число строк = 101, число колонок = 2
# Информация о признаках:
#                      тип  доля_nan   среднее_значение
# city              object        0.0               NaN
# average_flights  float64        0.0          5.494189

# %% [markdown]
# ### 4. Выбор топ-10 городов по количеству рейсов

# %%
top10_cities = df_q3.sort_values('average_flights', ascending = False).head(10)['city'].tolist()
top10_cities
# Out:
# ['Москва',
#  'Санкт-Петербург',
#  'Новосибирск',
#  'Красноярск',
#  'Екатеринбург',
#  'Ростов-на-Дону',
#  'Пермь',
#  'Брянск',
#  'Сочи',
#  'Ульяновск']

# %% [markdown]
# ### 5. Построить графики:
# * модели самолётов и количество рейсов
# * города и количество рейсов
# * топ-10 городов и количество рейсов;

# %%
fig, ax = plt.subplots(figsize = (7, 4))
df_q1.set_index('model')['flights_amount'].sort_values().plot(kind = 'barh', ax = ax)
plt.title('Кол-во рейсов в разрезе моделей самолетов', fontsize = 20)
plt.xlabel('кол-во рейсов')
plt.ylabel('модель самолета')
plt.show()

# %% [markdown]
# #### Выводы:
# * в сентябре 2018 года 3 модели самолетов совершили более 4000 рейсов : Cessna 208 Caravan, Bombardier CRJ-200, Sukhoi SuperJet-100
# * остальные модели совершили менее 1000

# %%
fig, ax = plt.subplots(figsize = (12, 20))
df_q3.set_index('city')['average_flights'].sort_values().plot(kind = 'barh', ax = ax)
plt.title('Среднее число рейсов в разрезе городов', fontsize = 20)
plt.xlabel('число рейсов')
plt.ylabel('город')
plt.show()

# %%
print('Доля городов, посещенных менее 10 раз = {:.2f}'.format((df_q3['average_flights']<10).mean()))
# Out:
# Доля городов, посещенных менее 10 раз = 0.92

# %%
df_q3_v2 = df_q3[df_q3['city'].isin(top10_cities)]
fig, ax = plt.subplots(figsize = (7, 4))
df_q3_v2.set_index('city')['average_flights'].sort_values().plot(kind = 'barh', ax = ax)
plt.title('Среднее число рейсов в разрезе городов (топ10)', fontsize = 20)
plt.xlabel('число рейсов')
plt.ylabel('город')
plt.show()

# %% [markdown]
# #### Выводы:
# * в сентябре 2018 года топ 3 городов по среднему числу рейсов составляют: Москва(130), Санкт-Петербург(31), Новосибирск(17)

# %% [markdown]
# ## Общий вывод:
# * в сентябре 2018 года топ 3 городов по среднему числу рейсов составляют: Москва(130), Санкт-Петербург(31), Новосибирск(17)
# * в сентябре 2018 92% городов приняли менее 10 рейсов
